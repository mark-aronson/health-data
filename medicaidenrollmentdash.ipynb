# %%
from matplotlib import pyplot as plt 
import pandas as pd 
import numpy as np
import datetime
import ipywidgets as widgets
from ipywidgets import interact

df = pd.read_csv('C://Users/aronsonm/Documents/HealthEquityDataJam/medicaidenrollment.csv')
df["report_date"] = pd.to_datetime(df["report_date"]).dt.date

# Plot State-by-state Medicaid enrollment
state_abrevs = df.state_abbreviation.unique()
baseline = datetime.date(year=2020,month=2,day=1)

statedf = df[(df['state_abbreviation']==state_abrevs[1]) & (df['final_report'] == 'Y')]
plotdates = statedf["report_date"].to_numpy()


@interact
def plotState(State=state_abrevs):
    plt.figure(figsize=(16,4))
    
    for i in range(len(state_abrevs)):
        statedf = df[(df['state_abbreviation']==state_abrevs[i]) & (df['final_report'] == 'Y')]
        dates = statedf["report_date"].to_numpy()
        enrollees = statedf["total_medicaid_and_chip_enrollment"].to_numpy()

        plt.subplot(1,2,1)
        plt.plot(dates[1::],enrollees[1::]-enrollees[np.where(dates==baseline)[0][0]],color=[.8,.8,.8],label=state_abrevs[i])

        plt.subplot(1,2,2)
        plt.plot(dates[1::],enrollees[1::]/enrollees[np.where(dates==baseline)[0][0]]-1,color=[.8,.8,.8],label=state_abrevs[i])
    
    statedf = df[(df['state_abbreviation']==State) & (df['final_report'] == 'Y')]
    dates = statedf["report_date"].to_numpy()
    enrollees = statedf["total_medicaid_and_chip_enrollment"].to_numpy()

    plt.subplot(1,2,1)
    plt.plot(dates[1::],enrollees[1::]-enrollees[np.where(dates==baseline)[0][0]],color='k',linewidth=2)

    plt.subplot(1,2,2)
    plt.plot(dates[1::],enrollees[1::]/enrollees[np.where(dates==baseline)[0][0]]-1,color='k',linewidth=2)
    
    ax = plt.subplot(1,2,1)
    ax.set_title('Additional Medicaid Enrollees since PHE',fontsize=18)
    ax.set_ylabel('Enrollees (Millions)',fontsize=18)
    ax.set_xlim([plotdates[1],plotdates[-1]])
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['right'].set_linewidth(0)
    ax.spines['top'].set_linewidth(0)
    ax.tick_params(axis='both',length=10,width=4,labelsize=18)

    ax = plt.subplot(1,2,2)
    ax.set_title('Percent Increase in Medicaid Enrollees since PHE',fontsize=18)
    ax.set_xlim([plotdates[1],plotdates[-1]])
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['right'].set_linewidth(0)
    ax.spines['top'].set_linewidth(0)
    ax.tick_params(axis='both',length=10,width=4,labelsize=18)

    plt.tight_layout()
# Out:
# interactive(children=(Dropdown(description='State', options=('AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', '…

# %%
df = pd.read_csv('C://Users/aronsonm/Documents/HealthEquityDataJam/StatePopulations.csv')

df
# Out:
#                     NAME      2010      2011      2012      2013      2014  \
# 0                Alabama   4785437   4799069   4815588   4830081   4841799
# 1                 Alaska    713910    722128    730443    737068    736283
# 2                Arizona   6407172   6472643   6554978   6632764   6730413
# 3               Arkansas   2921964   2940667   2952164   2959400   2967392
# 4             California  37319502  37638369  37948800  38260787  38596972
# 5               Colorado   5047349   5121108   5192647   5269035   5350101
# 6            Connecticut   3579114   3588283   3594547   3594841   3594524
# 7               Delaware    899593    907381    915179    923576    932487
# 8   District of Columbia    605226    619800    634924    650581    662328
